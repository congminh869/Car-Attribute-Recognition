# %%
import glob
import os 
import shutil
#shutil.copy2(source, destination)

path_source = '/home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all7/'
path_dst = '/home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/dataset/Coach2/'
path_label = '/home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/test_sample/img_detect/'
path_imgs = []
path_label_imgs = []
for name in glob.glob(path_source+'*.jpg'):
    path_imgs.append(name)
    
for name_label in glob.glob(path_label+'*.jpg'):
    path_label_imgs.append(name_label)
print(path_imgs[0])
print(len(path_imgs))
print('----------')
print(path_label_imgs[0])
print(len(path_label_imgs))
# Out:
# /home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all7/455_bus_16300112410_009063.jpg
# 4952
# ----------
# /home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/test_sample/img_detect/coach_red_large_1282.jpg
# 118

# %%
group = 'label'
globals()[group]={}

name_labels = []
for i in path_label_imgs:
    name = i.split('/')[-1]
    id_label = name.split('.')[0].split('_')[-1]
    attr = name.split('.')[0]
    if id_label not in globals()[group]:
        globals()[group][id_label]=[]
        globals()[group][id_label]= attr
label
# Out:
# {'1282': 'coach_red_large_1282',
#  '684': 'coach_red_large_684',
#  '1349': 'coach_gray_large_1349',
#  '732': 'coach_orange_large_732',
#  '507': 'coach_white_medium_507',
#  '1329': 'coach_red_large_1329',
#  '694': 'coach_gray_large_694',
#  '1123': 'coach_orange_large_1123',
#  '1134': 'coach_white_large_1134',
#  '48': 'coach_blue_large_48',
#  '512': 'coach_orange_large_512',
#  '1323': 'coach_red_large_1323',
#  '653': 'coach_blue-white_large_653',
#  '1232': 'coach_red_large_1232',
#  '325': 'coach_blue-white_large_325',
#  '1089': 'coach_gray_large_1089',
#  '516': 'coach_red_large_516',
#  '343': 'coach_blue-white_large_343',
#  '1132': 'coach_orange_large_1132',
#  '455': 'coach_blue-white_large_455',
#  '1090': 'coach_white_large_1090',
#  '720': 'coach_red_large_720',
#  '561': 'coach_orange_large_561',
#  '627': 'coach_gray_large_627',
#  '1310': 'coach_red_large_1310',
#  '813': 'coach_red_large_813',
#  '103': 'coach_red_large_103',
#  '312': 'coach_blue_large_312',
# ...

# %%
count = 2905
for i in path_imgs:
    name = i.split('/')[-1]
    id = name.split('_')[0]
    print(label[id]) 
    attrs = label[id].split('_')
    new_name = attrs[0]+'_'+attrs[1]+'_'+attrs[2]+'_'+str(count)+'a'+'.jpg'
    print(new_name)
    count +=1
    print('-')
#     print(i)
    os.rename(i,path_source+ new_name) 
#     break
# Out:
# coach_blue-white_large_455
# coach_blue-white_large_2905a.jpg
# -
# coach_red_large_1197
# coach_red_large_2906a.jpg
# -
# coach_orange_large_1048
# coach_orange_large_2907a.jpg
# -
# coach_green_large_395
# coach_green_large_2908a.jpg
# -
# coach_red_large_1
# coach_red_large_2909a.jpg
# -
# coach_red_large_1323
# coach_red_large_2910a.jpg
# -
# coach_red_large_1371
# coach_red_large_2911a.jpg
# -
# coach_yellow_large_881
# coach_yellow_large_2912a.jpg
# -
# coach_blue-white_large_1136
# coach_blue-white_large_2913a.jpg
# -
# coach_red-white_large_770
# coach_red-white_large_2914a.jpg
# -
# coach_blue-white_large_1136
# coach_blue-white_large_2915a.jpg
# -
# coach_orange-black_large_1235
# coach_orange-black_large_2916a.jpg
# -
# coach_blue-white_large_325
# coach_blue-white_large_2917a.jpg
# -
# coach_orange_large_989
# coach_orange_large_2918a.jpg
# -
# coach_red_large_516
# coach_red_large_2919a.jpg
# -
# coach_orange_large_28
# coach_orange_large_2920a.jpg
# -
# ...

# %%
path_source
# Out:
# '/home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all7/'

# %%
import glob
import os 
import shutil
#shutil.copy2(source, destination)

path_source = '/home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all77/'
path_dst = '/home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/dataset/Coach2/'
path_label = '/home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/test_sample/img_detect_plus/'
path_imgs = []
path_label_imgs = []
for name in glob.glob(path_source+'*.jpg'):
    path_imgs.append(name)
    
for name_label in glob.glob(path_label+'*.jpg'):
    path_label_imgs.append(name_label)
print(path_imgs[0])
print(len(path_imgs))
print('----------')
print(path_label_imgs[0])
print(len(path_label_imgs))
group = 'label'
globals()[group]={}

name_labels = []
for i in path_label_imgs:
    name = i.split('/')[-1]
    id_label = name.split('.')[0].split('_')[-1]
    attr = name.split('.')[0]
    if id_label not in globals()[group]:
        globals()[group][id_label]=[]
        globals()[group][id_label]= attr
        
count = 0#2905
for i in path_imgs:
    name = i.split('/')[-1]
    id = name.split('_')[0]
    print(label[id]) 
    attrs = label[id].split('_')
    new_name = attrs[0]+'_'+attrs[1]+'_'+attrs[2]+'_'+str(count)+'a'+'.jpg'
    print(new_name)
    count +=1
    print('-')
#     print(i)
    os.rename(i,path_source+ new_name)
# Out:
# /home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all77/395_bus_16300110550_472121.jpg
# 299
# ----------
# /home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/test_sample/img_detect_plus/coach_pink_large_472.jpg
# 11
# coach_yellow_large_395
# coach_yellow_large_0a.jpg
# -
# coach_blue-white_large_48
# coach_blue-white_large_1a.jpg
# -
# coach_gray_large_1048
# coach_gray_large_2a.jpg
# -
# coach_red_large_1186
# coach_red_large_3a.jpg
# -
# coach_yellow_large_395
# coach_yellow_large_4a.jpg
# -
# coach_red_large_510
# coach_red_large_5a.jpg
# -
# coach_blue-white_large_48
# coach_blue-white_large_6a.jpg
# -
# coach_red_large_510
# coach_red_large_7a.jpg
# -
# coach_gray_large_866
# coach_gray_large_8a.jpg
# -
# coach_blue-white_large_48
# coach_blue-white_large_9a.jpg
# -
# coach_gray_large_1048
# coach_gray_large_10a.jpg
# -
# coach_green_large_684
# ...

# %%
name = ['Uber Taxi',
'Vina Taxi',
'Grab Taxi',
'SAIGON Air Taxi',
'VinaSun Taxi',
'Taxi Saigontourrist',
'Taxi Mai Linh',
'Taxi Petrolimex',
'Taxi Hoàng Long',
'Taxi Savico',
'TAXI OPEN99',
'TAXI ABC',
'TAXI GROUP',
'TAXI THÀNH CÔNG',
'VIC TAXI',
'TAXI BA SAO',
'TAXI LONG BIÊN',
'TAXI SAO HÀ NỘI',
'SAO MAI TAXI',
'Sun Taxi',
'TAXI SÔNG ĐÀ',
'TAXI HOÀNG ANH',
'taxi Trung Kiên ',
'taxi 36',
'TAXI HOÀNG SA',
'TAXI TIÊN SA',
'TAXI HÀNG KHÔNG',
'TAXI PHÚ QUỐC',
'FUTA Taxi']

# %%
name
# Out:
# ['Uber Taxi',
#  'Vina Taxi',
#  'Grab Taxi',
#  'SAIGON Air Taxi',
#  'VinaSun Taxi',
#  'Taxi Saigontourrist',
#  'Taxi Mai Linh',
#  'Taxi Petrolimex',
#  'Taxi Hoàng Long',
#  'Taxi Savico',
#  'TAXI OPEN99',
#  'TAXI ABC',
#  'TAXI GROUP',
#  'TAXI THÀNH CÔNG',
#  'VIC TAXI',
#  'TAXI BA SAO',
#  'TAXI LONG BIÊN',
#  'TAXI SAO HÀ NỘI',
#  'SAO MAI TAXI',
#  'Sun Taxi',
#  'TAXI SÔNG ĐÀ',
#  'TAXI HOÀNG ANH',
#  'taxi Trung Kiên\xa0',
#  'taxi 36',
#  'TAXI HOÀNG SA',
#  'TAXI TIÊN SA',
#  'TAXI HÀNG KHÔNG',
#  'TAXI PHÚ QUỐC',
#  'FUTA Taxi']
