# %%
import glob
import numpy as np

# %%
path = '/home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all7/'
path_imgs = []
for name in glob.glob(path+'/*.jpg'):
    path_imgs.append(name)

# %%
len(path_imgs)
# Out:
# 4952

# %%
group = 'label'
globals()[group] = {}
# globals()[group]['ids'] = []
for name in path_imgs:
    name_img = name.split('/')[-1]
    id = name_img.split('_')[0]
    if id not in globals()[group]:
        globals()[group][id]= []
        globals()[group][id]= name_img
#     print(name_img)
#     print(id)
#     break

# %%
label
# Out:
# {'455': '455_bus_16300112410_009063.jpg',
#  '1197': '1197_bus_16300132250_939975.jpg',
#  '1048': '1048_bus_16300128760_11209.jpg',
#  '395': '395_bus_16300110820_165314.jpg',
#  '1': '1_bus_16300102830_494362.jpg',
#  '1323': '1323_bus_16300140840_422668.jpg',
#  '1371': '1371_bus_16300141690_544981.jpg',
#  '881': '881_bus_16300124370_654821.jpg',
#  '1136': '1136_bus_16300131830_4226.jpg',
#  '770': '770_bus_16300121360_047706.jpg',
#  '1235': '1235_bus_16300135300_88971.jpg',
#  '325': '325_bus_16300109750_621167.jpg',
#  '989': '989_bus_16300127760_102128.jpg',
#  '516': '516_bus_16300114980_713976.jpg',
#  '28': '28_bus_16300104110_394967.jpg',
#  '364': '364_bus_16300109770_403909.jpg',
#  '720': '720_bus_16300119980_311685.jpg',
#  '569': '569_bus_16300115890_961294.jpg',
#  '48': '48_bus_16300105100_165553.jpg',
#  '297': '297_bus_16300109100_196708.jpg',
#  '176': '176_bus_16300107930_406336.jpg',
#  '100': '100_bus_16300105720_890336.jpg',
# ...

# %%
len(label)
# Out:
# 118

# %%
import shutil
source = path = '/home/minh/Documents/minh/mqsolutions/object_tracking_yolov5/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/image_xe_khach_youtube/all/all7/'
destination = '/home/minh/Documents/minh/mqsolutions/detec_color/Person-Attribute-Recognition-MarketDuke/test_sample/img_detect'

for i in label:
    print(label[i])
    dest = shutil.copy2(source+label[i], destination)
#     break
# Out:
# 455_bus_16300112410_009063.jpg
# 1197_bus_16300132250_939975.jpg
# 1048_bus_16300128760_11209.jpg
# 395_bus_16300110820_165314.jpg
# 1_bus_16300102830_494362.jpg
# 1323_bus_16300140840_422668.jpg
# 1371_bus_16300141690_544981.jpg
# 881_bus_16300124370_654821.jpg
# 1136_bus_16300131830_4226.jpg
# 770_bus_16300121360_047706.jpg
# 1235_bus_16300135300_88971.jpg
# 325_bus_16300109750_621167.jpg
# 989_bus_16300127760_102128.jpg
# 516_bus_16300114980_713976.jpg
# 28_bus_16300104110_394967.jpg
# 364_bus_16300109770_403909.jpg
# 720_bus_16300119980_311685.jpg
# 569_bus_16300115890_961294.jpg
# 48_bus_16300105100_165553.jpg
# 297_bus_16300109100_196708.jpg
# 176_bus_16300107930_406336.jpg
# 100_bus_16300105720_890336.jpg
# 280_bus_16300108900_405188.jpg
# 507_bus_16300113230_608841.jpg
# 1274_bus_16300136750_107302.jpg
# 376_bus_16300110010_498839.jpg
# 806_bus_16300122310_090954.jpg
# 430_bus_16300111170_590468.jpg
# 743_bus_16300120660_986724.jpg
# 98_bus_16300105770_074286.jpg
# ...

# %%
label_list = ['black', 'blue', 'brown', 
              'bus', 'car', 'coach', 
              'gray', 'green', 
              'large', 
              'lorry', 
              'medium', 
              'orange', 'pink', 'red', 
              'sandy', 'truck', 
              'white', 'yellow']

# %%
for i in range(len(label_list)):
    print(str(i)+' : '+label_list[i])
# Out:
# 0 : black
# 1 : blue
# 2 : brown
# 3 : bus
# 4 : car
# 5 : coach
# 6 : gray
# 7 : green
# 8 : large
# 9 : lorry
# 10 : medium
# 11 : orange
# 12 : pink
# 13 : red
# 14 : sandy
# 15 : truck
# 16 : white
# 17 : yellow

# %%
color = [0,1,2,6,7,11,12,13,16,17]
size  = [8,10]
types = [3,4,5,9,14,15]

# %%
idx = 1
if idx in color:
    print('true')
# Out:
# true
